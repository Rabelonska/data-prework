# %%
import random

# %%
gestures = ["rock", "paper", "scissors"]

# %%
n_rounds = [1, 3, 5]

# %%
rounds_to_win = [1, 2, 3]

# %%
player_score = 0
cpu_score = 0

# %%
def gest_cpu():
    gest = random.choice(gestures)
    return gest

# %%
def gest_user():
    resp = False
    while resp is False:
        y = str(input("Please type your choice: "))        
        if y.lower() == "rock":
            resp = True            
            print("Let´s play")
            return y
        elif y.lower() == "paper":
            resp = True
            print("Let´s play")
            return y
        elif y.lower() == "scissors":
            resp = True
            print("Let´s play")
            return y

# %%
def play_jqp(us, pc):
    if us == "rock" and pc == "scissors":
        return 2
    elif us == "paper" and pc == "rock":
        return 2
    elif us == "scissors" and pc == "paper":
        return 2
    elif pc == "rock" and us == "scissors":
        return 1
    elif pc == "paper" and us == "rock":
        return 1
    elif pc == "scissors" and us == "paper":
        return 1
    else:
        return 0

# %%
gest_user()

# %%
def show_game():
    us = gest_user()
    pc = gest_cpu()
    result = play_jqp(us, pc)
    if result == 0:
        print(f"Player {us}, Computer {pc}. It´s a Tie!!")
    elif result == 1:
        print(f"Player {us}, Computer {pc}. Computer won!!")
    elif result == 2:
        print(f"Player {us}, Computer {pc}. Player won!!")

# %%
show_game()

# %%
import random

gestures2 = ["rock", "paper", "scissors", "lizard", "spock"]

n_of_wins = []
n_rounds = [1, 3, 5]
rounds_to_win = [1, 2, 3]


def gest_cpu():
    g = random.choice(gestures2)
    return g


def gest_user_lizard():    
    resp = False    
    while resp is False:
        y = str(input("Please type your choice: "))
        if y.lower() in gestures2:
            resp = True
            return y

def gest_user_rounds():
    resp = False    
    while resp is False:
        n = int(input("Please choose the number of rounds: "))
        if n in n_rounds:
            resp = True            
            print("Let´s play")
            return n
            

def play_jqp_lizard(y, g):
    n = gest_user_rounds()
    
    if y == "rock" and g == "scissors" or g == "lizard":
        return 2
    elif y == "paper" and g == "rock" or g == "spock":
        return 2
    elif y == "scissors" and g == "paper" or g == "lizard":
        return 2
    elif g == "rock" and y == "scissors" or y == "lizard":
        return 1
    elif g == "paper" and y == "rock" or y == "spock":
        return 1
    elif g == "scissors" and y == "paper" or y == "lizard":
        return 1
    else:
        return 0

def wins(y, g):
    n = gest_user_rounds() 
    player_score = 0
    cpu_score = 0
    numb = False
    
    while numb is False:
        
        y = gest_user_lizard()
        g = gest_cpu()
        pl = play_jqp_lizard(y, g)
        if pl == 0:
            cpu_score += 1
            player_score += 1
            print(f"It´s a tie! Play again.")
        elif pl == 1:
            cpu_score +=1
            if n == 1 and cpu_score == 1:
                return 1
                numb = True
            elif n == 3:
                if cpu_score == 2:
                    return 1
                    numb = True                  
                elif cpu_score == 2:
                    print("Computer 3")
                    print(cpu_score)
                    
            elif n == 5 and cpu_score != 3:
                print("computer 5")
                if cpu_score == 3:
                    return 1
                    numb = True
        elif pl == 2:
            player_score += 1
            if n == 1 and player_score == 1:
                return 2
                numb = True
            elif n == 3:
                if player_score == 2:
                    return 2
                    numb = True                                 
                else:
                    print("player 3")
                    print(player_score)
                    
            elif n == 5 and player_score != 3:
                print("player 5")
                if player_score == 3:
                    return 2
                    numb = True
            

def show_game_lizard():
    #y = gest_user_lizard()
    #g = gest_cpu()
    wn = wins(y, g)    
    
    if wn == 0:
        print(f"Player {y}, Computer {g}. It´s a Tie!!")
    elif wn == 1:
        print(f"Player {y}, Computer {g}. Computer won!!")
    elif wn == 2:
        print(f"Player {y}, Computer {g}. Player won!!")

# %%
show_game_lizard()

# %%
############# ESTE ESTÁ FUNCIONAL ####################################



import random

gestures2 = ["rock", "paper", "scissors", "lizard", "spock"]
n_of_wins = []
n_rounds = [1, 3, 5]
rounds_to_win = [1, 2, 3]


def inpt_rounds():
    resp = False    
    while resp is False:
        n = int(input("Please choose the number of rounds: "))
        if n in n_rounds:
            resp = True            
            return n

def game_play():
    ir = inpt_rounds()
    game = False    
    player_score = 0
    cpu_score = 0
    while game is False:
        game = False
        y = str(input("Please type your choice: "))
        if y.lower() in gestures2:
            g = random.choice(gestures2)
            
            if y == "rock" and g == "scissors" or g == "lizard":
                player_score += 1
                if ir == 1:
                    if player_score == 1:
                        print("Player WINS!")
                        game = True
                        return 2
                elif ir == 3:
                    if player_score == 1:
                        print("Player wins one out of three hands. Play again")
                    elif player_score == 2:
                        print("Player wins two out of three hands. WIN!!!")
                        game = True
                        return 2
                elif ir == 5:
                    if player_score == 1:
                        print("Player wins one out of five hands. Play again")
                    elif player_score == 2:
                        print("Player wins two out of five hands. Play again")
                    elif player_score == 3:
                        print("Player wins three out of five hands. WIN!!!")
                        game = True
                        return 2                
                    
            elif y == "paper" and g == "rock" or g == "spock":
                player_score += 1
                if ir == 1:
                    if player_score == 1:
                        print("Player WINS!")
                        game = True
                        return 2
                elif ir == 3:
                    if player_score == 1:
                        print("Player wins one out of three hands. Play again")
                    elif player_score == 2:
                        print("Player wins two out of three hands. WIN!!!")
                        game = True
                        return 2
                elif ir == 5:
                    if player_score == 1:
                        print("Player wins one out of five hands. Play again")
                    elif player_score == 2:
                        print("Player wins two out of five hands. Play again")
                    elif player_score == 3:
                        print("Player wins three out of five hands. WIN!!!")
                        game = True
                        return 2                
                
            elif y == "scissors" and g == "paper" or g == "lizard":
                player_score += 1
                if ir == 1:
                    if player_score == 1:
                        print("Player WINS!")
                        game = True
                        return 2
                elif ir == 3:
                    if player_score == 1:
                        print("Player wins one out of three hands. Play again")
                    elif player_score == 2:
                        print("Player wins two out of three hands. WIN!!!")
                        game = True
                        return 2
                elif ir == 5:
                    if player_score == 1:
                        print("Player wins one out of five hands. Play again")
                    elif player_score == 2:
                        print("Player wins two out of five hands. Play again")
                    elif player_score == 3:
                        print("Player wins three out of five hands. WIN!!!")
                        game = True
                        return 2                
                    
            elif g == "rock" and y == "scissors" or y == "lizard":
                cpu_score += 1
                if ir == 1:
                    if cpu_score == 1:
                        print("Computer WINS!")
                        game = True
                        return 1
                elif ir == 3:
                    if cpu_score == 1:
                        print("Computer wins one out of three hands. Play again")
                    elif player_score == 2:
                        print("Computer wins two out of three hands. WIN!!!")
                        game = True
                        return 1
                elif ir == 5:
                    if cpu_score == 1:
                        print("Computer wins one out of five hands. Play again")
                    elif player_score == 2:
                        print("Computer wins two out of five hands. Play again")
                    elif player_score == 3:
                        print("Computer wins three out of five hands. WIN!!!")
                        game = True
                        return 1                
                    
            elif g == "paper" and y == "rock" or y == "spock":
                cpu_score += 1
                if ir == 1:
                    if cpu_score == 1:
                        print("Computer WINS!")
                        game = True
                        return 1
                elif ir == 3:
                    if cpu_score == 1:
                        print("Computer wins one out of three hands. Play again")
                    elif player_score == 2:
                        print("Computer wins two out of three hands. WIN!!!")
                        game = True
                        return 1
                elif ir == 5:
                    if cpu_score == 1:
                        print("Computer wins one out of five hands. Play again")
                    elif player_score == 2:
                        print("Computer wins two out of five hands. Play again")
                    elif player_score == 3:
                        print("Computer wins three out of five hands. WIN!!!")
                        game = True
                        return 1                
                        
            elif g == "scissors" and y == "paper" or y == "lizard":
                cpu_score += 1
                if ir == 1:
                    if cpu_score == 1:
                        print("Computer WINS!")
                        game = True
                        return 1
                elif ir == 3:
                    if cpu_score == 1:
                        print("Computer wins one out of three hands. Play again")
                    elif player_score == 2:
                        print("Computer wins two out of three hands. WIN!!!")
                        game = True
                        return 1
                elif ir == 5:
                    if cpu_score == 1:
                        print("Computer wins one out of five hands. Play again")
                    elif player_score == 2:
                        print("Computer wins two out of five hands. Play again")
                    elif player_score == 3:
                        print("Computer wins three out of five hands. WIN!!!")
                        game = True
                        return 1                
            else:
                player_score +=1
                cpu_score += 1
                print("It´s a tie! Play again")            
        else:
            print("Invalid gesture!")

# %%
# Out:
# Please choose the number of rounds: 3
# Please type your choice: rock
# Player wins one out of three hands. Play again
# Please type your choice: rock
# Player wins two out of three hands. WIN!!!
# 2
